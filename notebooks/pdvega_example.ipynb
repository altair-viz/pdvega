# %% [markdown]
# # ``pdvega``: Pandas Plotting API to Vega-Lite
#
# ``pdvega`` is an experimental package that enables the creation of Vega-Lite plots using the pandas plotting API.
#
# See http://github.com/jakevdp/pdvega
#
# This is currently a proof-of-concept, and far from complete.

# %%
# import adds the vgplot attribute to Series and DataFrames
import pdvega

import pandas as pd
import numpy as np

t = np.arange(100)
df = pd.DataFrame({'x': np.sin(t / 10),
                   'y': np.cos(t / 10)},
                  index=t)

# %% [markdown]
# ## Line Plots

# %%
# %matplotlib inline
df.plot.line();

# %%
df.vgplot.line()
# Out:
# <div class="vega-embed" id="e2513115-8370-48ef-87d8-77f9bdbdcaeb"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Scatter Plots

# %%
df.plot.scatter(x='x', y='y');

# %%
df.vgplot.scatter(x='x', y='y')
# Out:
# <div class="vega-embed" id="9e1d52c8-1b87-454f-9c1b-941775822600"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Bar Plots

# %% [markdown]
# ### Unstacked

# %%
df.iloc[5:15].plot.bar();

# %%
df.iloc[5:15].vgplot.bar()
# Out:
# <div class="vega-embed" id="81c4d932-1bcd-4277-af12-93709e8013d7"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ### Stacked

# %%
df.iloc[5:15].plot.bar(stacked=True);

# %%
df.iloc[5:15].vgplot.bar(stacked=True)
# Out:
# <div class="vega-embed" id="ffe25e7f-1480-4be1-9501-2ea0ac3a5398"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Area Plots

# %%
df = pd.DataFrame({'x': np.random.rand(50),
                   'y': np.random.rand(50)})

# %%
df.plot.area();

# %%
df.vgplot.area()
# Out:
# <div class="vega-embed" id="dc01cb95-5743-4698-9907-90213de41e46"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
df.plot.area(stacked=False);

# %%
df.vgplot.area(stacked=False)
# Out:
# <div class="vega-embed" id="42d74c68-d68f-4a8a-a79d-413025c827e8"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## More to come...

# %% [markdown]
# More functionality soon...
