# %% [markdown]
# # ``pdvega``: Pandas Plotting API to Vega-Lite
#
# ``pdvega`` is an experimental package that enables the creation of Vega-Lite plots using the pandas plotting API.
#
# This is currently a proof-of-concept, and far from complete.

# %%
# import adds the vgplot attribute to Series and DataFrames
import pdvega

import pandas as pd
import numpy as np

t = np.arange(100)
df = pd.DataFrame({'x': np.sin(t / 10),
                   'y': np.cos(t / 10)},
                  index=t)

# %% [markdown]
# ## Line Plots

# %%
# %matplotlib inline
df.plot.line();

# %%
df.vgplot.line()
# Out:
# <div class="vega-embed" id="51463a79-3055-483b-9861-16297c42f5d2"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Scatter Plots

# %%
df.plot.scatter(x='x', y='y');

# %%
df.vgplot.scatter(x='x', y='y')
# Out:
# <div class="vega-embed" id="b5933027-840b-429e-84f5-2190bfee4ec3"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Bar Plots

# %%
df.iloc[5:15].plot.bar();

# %%
df.iloc[5:15].vgplot.bar()
# Out:
# <div class="vega-embed" id="64c26487-664b-45d8-a6b5-f6285d6a62ef"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## More to come...

# %% [markdown]
# More functionality soon...
